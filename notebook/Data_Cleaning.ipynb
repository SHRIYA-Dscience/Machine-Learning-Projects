# %% [markdown]
# ### Pandas and Data Cleaning
# **pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.**
# - it is used for data cleaning , data manipulation, data engineering and also for data vistualization.
# - It is easy to use access and control the data.

# %%
! pip install pandas
# Out:
# Looking in indexes: https://__token__:****@gitlab.com/api/v4/projects/68129097/packages/pypi/simple
# Requirement already satisfied: pandas in d:\machine-learning-projects\venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\machine-learning-projects\venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\machine-learning-projects\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\machine-learning-projects\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\machine-learning-projects\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\machine-learning-projects\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: 401 Error, Credentials not correct for https://gitlab.com/api/v4/projects/68129097/packages/pypi/simple/pip/

# %%
import pandas as pd

# %%
scores = pd.read_csv("data/exams.csv")

# %%
pd.set_option("display.max_columns",None)
scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
# See the number of rows and columns
scores.shape
# Out:
# (1000, 8)

# %%
# check the coulmns of dataframes
scores.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# take summary of dataset
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# if you ckeck the datatype of each columns
scores.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# check the statistic summary of data 
scores.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.810000      70.382000      69.140000
# std      15.250196      14.107413      15.025917
# min      15.000000      25.000000      15.000000
# 25%      58.000000      61.000000      59.000000
# 50%      68.000000      70.500000      70.000000
# 75%      79.250000      80.000000      80.000000
# max     100.000000     100.000000     100.000000

# %%
# select specific column from dataframe 
scores['lunch']
# Out:
# 0          standard
# 1          standard
# 2      free/reduced
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996        standard
# 997        standard
# 998        standard
# 999        standard
# Name: lunch, Length: 1000, dtype: object

# %%
# another way
scores.lunch
# Out:
# 0          standard
# 1          standard
# 2      free/reduced
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996        standard
# 997        standard
# 998        standard
# 999        standard
# Name: lunch, Length: 1000, dtype: object

# %%
# select multiple columns 
scores_filters = scores[['gender','lunch','reading score']]
scores_filters
# Out:
#      gender         lunch  reading score
# 0    female      standard             70
# 1      male      standard             93
# 2    female  free/reduced             76
# 3      male  free/reduced             70
# 4    female      standard             85
# ..      ...           ...            ...
# 995    male      standard             77
# 996    male      standard             66
# 997  female      standard             86
# 998    male      standard             72
# 999    male      standard             47
#
# [1000 rows x 3 columns]

# %%
# Check unique value of specific columns
scores['parental level of education'].unique()
# Out:
# array(['some college', "associate's degree", 'some high school',
#        "bachelor's degree", "master's degree", 'high school'],
#       dtype=object)

# %%
scores['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          224
# high school           215
# associate's degree    204
# some high school      177
# bachelor's degree     105
# master's degree        75
# Name: count, dtype: int64

# %%
# Check the minimum and maximum values of columns 
print(scores['gender'].max())
print(scores['writing score'].min())
print(scores[['gender','writing score']].max())
# Out:
# male
# 15
# gender           male
# writing score     100
# dtype: object

# %% [markdown]
# 1. whcich race has highest marks in reading scores?
# 2. what is unique values of test preparation course?
# 3. minmum marks of females in maths scores?
# 4. According to lunch which has highest scores in writing?

# %%
# copy the dataFrame
data_clean = scores.copy()
data_clean.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
# rename the coulmns name
data_clean.rename({'race/ethnicity':'Race','test preparation course':'Total Remarks'},axis=1,inplace=True)

# %%
data_clean.head()
# Out:
#    gender     Race parental level of education         lunch Total Remarks  \
# 0  female  group D                some college      standard     completed
# 1    male  group D          associate's degree      standard          none
# 2  female  group D                some college  free/reduced          none
# 3    male  group B                some college  free/reduced          none
# 4  female  group D          associate's degree      standard          none
#
#    math score  reading score  writing score
# 0          59             70             78
# 1          96             93             87
# 2          57             76             77
# 3          70             70             63
# 4          83             85             86

# %%
data_clean.dtypes
# Out:
# gender                         object
# Race                           object
# parental level of education    object
# lunch                          object
# Total Remarks                  object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# change datatype of specific column.
data_clean = data_clean.astype({'math score':'float'})

# %%
# Another way
data_clean['math score'] = data_clean['math score'].astype('str')

# %%
data_clean.dtypes
# Out:
# gender                         object
# Race                           object
# parental level of education    object
# lunch                          object
# Total Remarks                  object
# math score                     object
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data_clean.head()
# Out:
#    gender     Race parental level of education         lunch Total Remarks  \
# 0  female  group D                some college      standard     completed
# 1    male  group D          associate's degree      standard          none
# 2  female  group D                some college  free/reduced          none
# 3    male  group B                some college  free/reduced          none
# 4  female  group D          associate's degree      standard          none
#
#   math score  reading score  writing score
# 0       59.0             70             78
# 1       96.0             93             87
# 2       57.0             76             77
# 3       70.0             70             63
# 4       83.0             85             86

# %%
# drops columns 
data_clean.drop(['lunch','Race'],axis=1,inplace=True)

# %%
data_clean.head()
# Out:
#    gender parental level of education Total Remarks math score  reading score  \
# 0  female                some college     completed       59.0             70
# 1    male          associate's degree          none       96.0             93
# 2  female                some college          none       57.0             76
# 3    male                some college          none       70.0             70
# 4  female          associate's degree          none       83.0             85
#
#    writing score
# 0             78
# 1             87
# 2             77
# 3             63
# 4             86

# %%
data_clean['parental level of education'] = data_clean['parental level of education'].str.split()

# %%
data_clean.head()
# Out:
#    gender parental level of education Total Remarks math score  reading score  \
# 0  female             [some, college]     completed       59.0             70
# 1    male       [associate's, degree]          none       96.0             93
# 2  female             [some, college]          none       57.0             76
# 3    male             [some, college]          none       70.0             70
# 4  female       [associate's, degree]          none       83.0             85
#
#    writing score
# 0             78
# 1             87
# 2             77
# 3             63
# 4             86

# %%
data_clean['parental level of education']
# Out:
# 0            [some, college]
# 1      [associate's, degree]
# 2            [some, college]
# 3            [some, college]
# 4      [associate's, degree]
#                ...
# 995          [some, college]
# 996          [some, college]
# 997           [high, school]
# 998           [high, school]
# 999           [high, school]
# Name: parental level of education, Length: 1000, dtype: object

# %%
# Handler missing values
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   parental level of education  1000 non-null   object
#  2   Total Remarks                1000 non-null   object
#  3   math score                   1000 non-null   object
#  4   reading score                1000 non-null   int64
#  5   writing score                1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %% [markdown]
# ### Handler missing values

# %%
import numpy as np
ser_1 = pd.Series([1,2],dtype = np.int64).reindex([0,1,2])
ser_1
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
ser_2 = pd.Series([True,False], dtype= np.bool_).reindex([0,1,2])
print(ser_2)
ser_3 = pd.Series([1,2], dtype=np.dtype("timedelta64[ns]")).reindex([0,1,2])
print(ser_3)
ser_4 = pd.Series([1,2], dtype=np.dtype("datetime64[ns]")).reindex([0,1,2])
print(ser_4)
# Out:
# 0     True
# 1    False
# 2      NaN
# dtype: object
# 0   0 days 00:00:00.000000001
# 1   0 days 00:00:00.000000002
# 2                         NaT
# dtype: timedelta64[ns]
# 0   1970-01-01 00:00:00.000000001
# 1   1970-01-01 00:00:00.000000002
# 2                             NaT
# dtype: datetime64[ns]

# %% [markdown]
# **How to check null values?**

# %%
import pandas as pd 
import numpy as np

# %%
# Load data 
employee = pd.read_csv("data/employees.csv")

# %%
# Read first five rows
employee.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
nvalues = employee.isnull()
nvalues
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# 3                False  False
# 4                False  False
# ..                 ...    ...
# 995              False  False
# 996              False  False
# 997              False  False
# 998              False  False
# 999              False  False
#
# [1000 rows x 8 columns]

# %%
bool_series = pd.isnull(employee['Gender'])
new_missing_values = employee[bool_series]
new_missing_values
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# 27              False                 Legal
# 31              False               Product
# 41               True  Business Development
# ..                ...                   ...
# 961             False                 Legal
# 972              True                 Sales
# 985             False                 Legal
# 989             False                 Legal
# 995             False          Distribution
#
# [145 rows x 8 columns]

# %%
employee.isna()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# 3                False  False
# 4                False  False
# ..                 ...    ...
# 995              False  False
# 996              False  False
# 997              False  False
# 998              False  False
# 999              False  False
#
# [1000 rows x 8 columns]

# %%
msg = pd.notnull(employee['Gender'])
new = employee[msg]
display(new)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 994              True             Marketing
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# **Filling Missing Values in Pandas**

# %%
# fill the zero value where data is missing in dataset
employee.fillna(0)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry       0  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
# Fill with Previous Value (Forward Fill)
employee.fillna(method='pad')
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_33728\2158951190.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   employee.fillna(method='pad')
# C:\Users\shriy\AppData\Local\Temp\ipykernel_33728\2158951190.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   employee.fillna(method='pad')
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry    Male  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
# Fill with Next Value (Backward Fill)
employee.fillna(method='bfill')
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_33728\2227326196.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   employee.fillna(method='bfill')
# C:\Users\shriy\AppData\Local\Temp\ipykernel_33728\2227326196.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   employee.fillna(method='bfill')
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry    Male  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True               Finance
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employee[20:40]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# 23        NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 24       John    Male    7/1/1992        10:08 PM   97950   13.873
# 25        NaN    Male   10/8/2012         1:12 AM   37076   18.576
# 26      Craig    Male   2/27/2000         7:45 AM   37598    7.757
# 27      Scott     NaN   7/11/1991         6:58 PM  122367    5.218
# 28      Terry    Male  11/27/1981         6:30 PM  124008   13.464
# 29   Benjamin    Male   1/26/2005        10:06 PM   79529    7.008
# 30  Christina  Female    8/6/2002         1:19 PM  118780    9.096
# 31      Joyce     NaN   2/20/2005         2:40 PM   88657   12.752
# 32        NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 33       Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 34      Jerry    Male   1/10/2004        12:56 PM   95734   19.096
# 35    Theresa  Female  10/10/2006         1:12 AM   85182   16.675
# 36     Rachel  Female   2/16/2009         8:47 PM  142032   12.599
# 37      Linda  Female  10/19/1981         8:49 PM   57427    9.557
# 38  Stephanie  Female   9/13/1986         1:52 AM   36844    5.574
# 39        NaN    Male   1/29/2016         2:33 AM  122173    7.797
#
#    Senior Management                  Team
# 20              True                 Legal
# 21             False             Marketing
# 22              True       Client Services
# 23               NaN                   NaN
# 24             False       Client Services
# 25               NaN       Client Services
# 26              True             Marketing
# 27             False                 Legal
# 28              True       Client Services
# 29              True                 Legal
# 30              True           Engineering
# 31             False               Product
# 32               NaN                   NaN
# 33             False  Business Development
# 34             False       Client Services
# 35             False                 Sales
# 36             False  Business Development
# 37              True       Client Services
# 38              True  Business Development
# 39               NaN       Client Services

# %%
employee['Gender'].fillna('No Gender',inplace=True)
employee[20:40]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua  No Gender    3/8/2012         1:58 AM   90816   18.816
# 23        NaN       Male   6/14/2012         4:19 PM  125792    5.042
# 24       John       Male    7/1/1992        10:08 PM   97950   13.873
# 25        NaN       Male   10/8/2012         1:12 AM   37076   18.576
# 26      Craig       Male   2/27/2000         7:45 AM   37598    7.757
# 27      Scott  No Gender   7/11/1991         6:58 PM  122367    5.218
# 28      Terry       Male  11/27/1981         6:30 PM  124008   13.464
# 29   Benjamin       Male   1/26/2005        10:06 PM   79529    7.008
# 30  Christina     Female    8/6/2002         1:19 PM  118780    9.096
# 31      Joyce  No Gender   2/20/2005         2:40 PM   88657   12.752
# 32        NaN       Male   8/21/1998         2:27 PM  122340    6.417
# 33       Jean     Female  12/18/1993         9:07 AM  119082   16.180
# 34      Jerry       Male   1/10/2004        12:56 PM   95734   19.096
# 35    Theresa     Female  10/10/2006         1:12 AM   85182   16.675
# 36     Rachel     Female   2/16/2009         8:47 PM  142032   12.599
# 37      Linda     Female  10/19/1981         8:49 PM   57427    9.557
# 38  Stephanie     Female   9/13/1986         1:52 AM   36844    5.574
# 39        NaN       Male   1/29/2016         2:33 AM  122173    7.797
#
#    Senior Management                  Team
# 20              True                 Legal
# 21             False             Marketing
# 22              True       Client Services
# 23               NaN                   NaN
# 24             False       Client Services
# 25               NaN       Client Services
# 26              True             Marketing
# 27             False                 Legal
# 28              True       Client Services
# 29              True                 Legal
# 30              True           Engineering
# 31             False               Product
# 32               NaN                   NaN
# 33             False  Business Development
# 34             False       Client Services
# 35             False                 Sales
# 36             False  Business Development
# 37              True       Client Services
# 38              True  Business Development
# 39               NaN       Client Services

# %%
# Use replace() function to replace NaN values with a specific value.
employee[20:30]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua  No Gender    3/8/2012         1:58 AM   90816   18.816
# 23        NaN       Male   6/14/2012         4:19 PM  125792    5.042
# 24       John       Male    7/1/1992        10:08 PM   97950   13.873
# 25        NaN       Male   10/8/2012         1:12 AM   37076   18.576
# 26      Craig       Male   2/27/2000         7:45 AM   37598    7.757
# 27      Scott  No Gender   7/11/1991         6:58 PM  122367    5.218
# 28      Terry       Male  11/27/1981         6:30 PM  124008   13.464
# 29   Benjamin       Male   1/26/2005        10:06 PM   79529    7.008
#
#    Senior Management             Team
# 20              True            Legal
# 21             False        Marketing
# 22              True  Client Services
# 23               NaN              NaN
# 24             False  Client Services
# 25               NaN  Client Services
# 26              True        Marketing
# 27             False            Legal
# 28              True  Client Services
# 29              True            Legal

# %%
employee.replace(to_replace=np.nan, value=100)
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   100
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employee.isna().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management    67
# Team                 43
# dtype: int64

# %%
# This is not working right now. 
# new_employee = employee.interpolate(method='linear',limit_direction='forward')
employee.interpolate(method ='linear', limit_direction ='forward')
# new_employee.head(10)
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_33728\1820111417.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   employee.interpolate(method ='linear', limit_direction ='forward')
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employee.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# 4              True       Client Services
# 5             False                 Legal
# 6              True               Product
# 7               NaN               Finance
# 8              True           Engineering
# 9              True  Business Development

# %% [markdown]
# **Dropping Missing Values in Pandas**
#
# The dropna() function used to removes rows or columns with NaN values. It can be used to drop data based on different conditions.

# %%
employee.dropna()
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis       Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [899 rows x 8 columns]

# %%
# We can drop rows where all values are missing using dropna(how='all').

employee.dropna(how='all')
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
# To remove columns that contain at least one missing value we use dropna(axis=1).
employee.dropna(axis=1)
# Out:
#         Gender  Start Date Last Login Time  Salary  Bonus %
# 0         Male    8/6/1993        12:42 PM   97308    6.945
# 1         Male   3/31/1996         6:53 AM   61933    4.170
# 2       Female   4/23/1993        11:17 AM  130590   11.858
# 3         Male    3/4/2005         1:00 PM  138705    9.340
# 4         Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...         ...             ...     ...      ...
# 995  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996       Male   1/31/1984         6:30 AM   42392   19.675
# 997       Male   5/20/2013        12:39 PM   96914    1.421
# 998       Male   4/20/2013         4:45 PM   60500   11.985
# 999       Male   5/15/2012         6:24 PM  129949   10.169
#
# [1000 rows x 5 columns]

# %%
new1_employee = employee.dropna(axis=0,how='any')
print("Old data frame length:", len(employee))
print("New data frame length:", len(new1_employee))
print("Rows with at least one missing value:", (len(employee) - len(new1_employee)))
# Out:
# Old data frame length: 1000
# New data frame length: 899
# Rows with at least one missing value: 101
